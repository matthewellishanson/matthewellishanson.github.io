# %% [markdown]
# # Analysis of Desmond Bane's first 10 games vs his last 10 games

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime

# %%
data = pd.read_csv('../assets/bane.csv')
